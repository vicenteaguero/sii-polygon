# %%
# %reload_ext autoreload
# %autoreload 2

from sii_polygons.plotting import plot_map
from sii_polygons.requests import load_map

# %% [markdown]
# # Tutorial: Obtener mapas del SII

# %%
map = load_map(
    comuna='curico',
    comuna_id=7101,
    xmin=-7930265.247558751,
    xmax=-7930188.810530465,
    ymin=-4162607.686354127,
    ymax=-4162531.2493258417,
    size=256
)

# %%
plot_map(map)
